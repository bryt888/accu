# %% [markdown]
# ### WF-UNet
# - **Paper**: [WF-UNet: Weather Fusion UNet for Precipitation Nowcasting](https://arxiv.org/abs/2302.04102)
# - **Github**: https://github.com/christoskaparakis/WF-UNet
# ![image.png](attachment:image.png)

# %% [markdown]
# ### KARINA: AN EFFICIENT DEEP LEARNING MODEL FOR GLOBAL WEATHER FORECAST
# - **Paper**:[KARINA: AN EFFICIENT DEEP LEARNING MODEL FOR GLOBAL
# WEATHER FORECAST](https://arxiv.org/pdf/2403.10555v1)
# - **Code**: https://github.com/jmj2316/KARINA
# ![image.png](attachment:image.png)

# %% [markdown]
# ### rain nowcasting with fusion of rainfall and wind data
# - **Github**:[rain-nowcasting-with-fusion-of-rainfall-and-wind-data-article](https://github.com/VincentBouget/rain-nowcasting-with-fusion-of-rainfall-and-wind-data-article/tree/main)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ERA5 to CERRA via Diffusion Models
# - **Github**: https://github.com/fmerizzi/ERA5-to-CERRA-via-Diffusion-Models
# ![image.png](attachment:image.png)
#
# [Animated Image](https://github.com/fmerizzi/ERA5-to-CERRA-via-Diffusion-Models/raw/main/images/ensemble.gif)

# %% [markdown]
# ### Precipitation nowcasting with generative diffusion models
# - **Paper**:[Precipitation nowcasting with generative diffusion models](https://arxiv.org/abs/2308.06733)
# - **Github**: https://github.com/fmerizzi/Precipitation-nowcasting-with-generative-diffusion-models?tab=readme-ov-file
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - [Nowcasting Heavy Rainfall With Convolutional Long Short-Term Memory Networks: A Pixelwise Modeling Approach](https://ieeexplore.ieee.org/document/10487101)
