# %% [markdown]
# # RNN Related
#
# ### 1. PredRNN: Recurrent Neural Networks for Predictive Learning using Spatiotemporal LSTMs
# - **Paper**: https://papers.nips.cc/paper_files/paper/2017/hash/e5f6ad6ce374177eef023bf5d0c018b6-Abstract.html
# - **Github**: https://github.com/thuml/predrnn-pytorch?tab=readme-ov-file
#
# #### Examples from Github
# ![image.png](attachment:image.png)
#
# #### My Training result (1000 rounds) on Himawari9 Satellite IR Enhances images
# - first row is ground truth, send row are predicted frames. we can conmpare them directly
# - looks like only first 3 frames are usful
# - more training rounds and data could get better
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # UNet Related

# %% [markdown]
# ### 1. Pure Radar images training with UNet
# - **Github**: https://github.com/MIT-AI-Accelerator/sevir_challenges/blob/main/radar_nowcasting/RadarNowcastBenchmarks.ipynb
# - 13 frames as inputs
# - 12 frames will be generated as output
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Fusion of Rain Radar Images and Wind Forecasts in a Deep Learning Model Applied to Rain Nowcasting
# - **Paper**: https://arxiv.org/pdf/2012.05015
# - **Github**: https://github.com/VincentBouget/rain-nowcasting-with-fusion-of-rainfall-and-wind-data-article

# %% [markdown]
# ### 3. WF-UNet: Weather Fusion UNet for Precipitation Nowcasting
# - **Paper**:https://arxiv.org/abs/2302.04102
# - **Github**: https://github.com/christoskaparakis/WF-UNet?tab=readme-ov-file
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
